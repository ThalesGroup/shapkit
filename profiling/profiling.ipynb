# %%
import numpy as np
import pandas as pd

# %load_ext autoreload
# %load_ext line_profiler
# %load_ext Cython
# %autoreload 2

from shapkit.shapley_values import ShapleyValues
from shapkit.monte_carlo_shapley import MonteCarloShapley
from shapkit.sgd_shapley import SGDshapley

# %%
def generate_sample(dim, n_samples, rho=0):
    """
    Generate a dataset of independent Gaussian features
    """
    mu = np.zeros(dim)
    sigma = np.ones((dim, dim)) * rho
    np.fill_diagonal(sigma, [1] * dim)
    # Simulation
    X = np.random.multivariate_normal(mean=mu, cov=sigma, size=n_samples)
    df_X = pd.DataFrame(X, columns=['x'+str(i) for i in range(1, dim+1)])
    return df_X

d, n_samples = 5, 100
X = generate_sample(d, n_samples)
y = np.zeros(len(X))
for i in range(len(X)):
    phi_x = np.sqrt(.5 * np.pi) * np.exp(-0.5 * X.values[i] ** 2)
    y[i] = np.prod(phi_x)
    
n = 2**d - 2
def fc(x):
    phi_x = np.sqrt(.5 * np.pi) * np.exp(-0.5 * x ** 2)
    return np.prod(phi_x)
print("dimension = {0} ; nb of coalitions = {1}".format(str(d), str(n)))
# Out:
# dimension = 5 ; nb of coalitions = 30

# %%
idx_r, idx_x = np.random.choice(np.arange(len(X)), size=2, replace=False)
r = X.iloc[idx_r,:]
x = X.iloc[idx_x,:]

# %% [markdown]
# #### Shapley Values

# %%
# %timeit ShapleyValues(x=x, fc=fc, ref=r)
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 243.38it/s]
# 100%|██████████| 5/5 [00:00<00:00, 245.23it/s]
# 100%|██████████| 5/5 [00:00<00:00, 225.92it/s]
# 100%|██████████| 5/5 [00:00<00:00, 245.67it/s]
# 100%|██████████| 5/5 [00:00<00:00, 287.22it/s]
# 100%|██████████| 5/5 [00:00<00:00, 278.98it/s]
# 100%|██████████| 5/5 [00:00<00:00, 270.39it/s]
# 100%|██████████| 5/5 [00:00<00:00, 260.85it/s]
# 100%|██████████| 5/5 [00:00<00:00, 204.57it/s]
# 100%|██████████| 5/5 [00:00<00:00, 192.21it/s]
# 100%|██████████| 5/5 [00:00<00:00, 175.78it/s]
# 100%|██████████| 5/5 [00:00<00:00, 161.01it/s]
# 100%|██████████| 5/5 [00:00<00:00, 261.89it/s]
# 100%|██████████| 5/5 [00:00<00:00, 304.45it/s]
# 100%|██████████| 5/5 [00:00<00:00, 215.67it/s]
# 100%|██████████| 5/5 [00:00<00:00, 283.21it/s]
# 100%|██████████| 5/5 [00:00<00:00, 327.80it/s]
# 100%|██████████| 5/5 [00:00<00:00, 275.69it/s]
# 100%|██████████| 5/5 [00:00<00:00, 315.17it/s]
# 100%|██████████| 5/5 [00:00<00:00, 312.75it/s]
# 100%|██████████| 5/5 [00:00<00:00, 284.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 319.44it/s]
# 100%|██████████| 5/5 [00:00<00:00, 298.01it/s]
# 100%|██████████| 5/5 [00:00<00:00, 339.03it/s]
# 100%|██████████| 5/5 [00:00<00:00, 298.83it/s]
# 100%|██████████| 5/5 [00:00<00:00, 305.20it/s]
# 100%|██████████| 5/5 [00:00<00:00, 305.16it/s]
# 100%|██████████| 5/5 [00:00<00:00, 298.11it/s]
# 100%|██████████| 5/5 [00:00<00:00, 322.65it/s]
# 100%|██████████| 5/5 [00:00<00:00, 289.99it/s]
# 100%|██████████| 5/5 [00:00<00:00, 333.80it/s]
# 100%|██████████| 5/5 [00:00<00:00, 292.44it/s]
# 100%|██████████| 5/5 [00:00<00:00, 317.81it/s]
# 100%|██████████| 5/5 [00:00<00:00, 267.85it/s]
# 100%|██████████| 5/5 [00:00<00:00, 292.35it/s]
# 100%|██████████| 5/5 [00:00<00:00, 250.22it/s]
# 100%|██████████| 5/5 [00:00<00:00, 277.69it/s]
# 100%|██████████| 5/5 [00:00<00:00, 351.94it/s]
# 100%|██████████| 5/5 [00:00<00:00, 286.77it/s]
# 100%|██████████| 5/5 [00:00<00:00, 241.69it/s]
# 100%|██████████| 5/5 [00:00<00:00, 335.33it/s]
# 100%|██████████| 5/5 [00:00<00:00, 296.72it/s]
# 100%|██████████| 5/5 [00:00<00:00, 297.59it/s]
# 100%|██████████| 5/5 [00:00<00:00, 275.13it/s]
# 100%|██████████| 5/5 [00:00<00:00, 292.55it/s]
# 100%|██████████| 5/5 [00:00<00:00, 295.47it/s]
# 100%|██████████| 5/5 [00:00<00:00, 266.15it/s]
# 100%|██████████| 5/5 [00:00<00:00, 289.66it/s]
# 100%|██████████| 5/5 [00:00<00:00, 291.55it/s]
# 100%|██████████| 5/5 [00:00<00:00, 288.63it/s]
# 100%|██████████| 5/5 [00:00<00:00, 307.56it/s]
# 100%|██████████| 5/5 [00:00<00:00, 293.57it/s]
# 100%|██████████| 5/5 [00:00<00:00, 278.42it/s]
# 100%|██████████| 5/5 [00:00<00:00, 296.41it/s]
# 100%|██████████| 5/5 [00:00<00:00, 185.96it/s]
# 100%|██████████| 5/5 [00:00<00:00, 262.14it/s]
# 100%|██████████| 5/5 [00:00<00:00, 307.37it/s]
# 100%|██████████| 5/5 [00:00<00:00, 191.30it/s]
# 100%|██████████| 5/5 [00:00<00:00, 285.84it/s]
# 100%|██████████| 5/5 [00:00<00:00, 196.22it/s]
# 100%|██████████| 5/5 [00:00<00:00, 187.79it/s]
# 100%|██████████| 5/5 [00:00<00:00, 299.32it/s]
# 100%|██████████| 5/5 [00:00<00:00, 296.03it/s]
# 100%|██████████| 5/5 [00:00<00:00, 287.35it/s]
# 100%|██████████| 5/5 [00:00<00:00, 297.31it/s]
# 100%|██████████| 5/5 [00:00<00:00, 306.69it/s]
# 100%|██████████| 5/5 [00:00<00:00, 282.90it/s]
# 100%|██████████| 5/5 [00:00<00:00, 298.45it/s]
# 100%|██████████| 5/5 [00:00<00:00, 321.70it/s]
# 100%|██████████| 5/5 [00:00<00:00, 270.35it/s]
# 100%|██████████| 5/5 [00:00<00:00, 321.72it/s]
# 100%|██████████| 5/5 [00:00<00:00, 267.31it/s]
# 100%|██████████| 5/5 [00:00<00:00, 347.28it/s]
# 100%|██████████| 5/5 [00:00<00:00, 296.75it/s]
# 100%|██████████| 5/5 [00:00<00:00, 293.34it/s]
# 100%|██████████| 5/5 [00:00<00:00, 314.17it/s]
# 100%|██████████| 5/5 [00:00<00:00, 259.83it/s]
# 100%|██████████| 5/5 [00:00<00:00, 161.49it/s]
# 100%|██████████| 5/5 [00:00<00:00, 366.47it/s]
# 100%|██████████| 5/5 [00:00<00:00, 301.97it/s]
# 100%|██████████| 5/5 [00:00<00:00, 349.61it/s]
# 20.6 ms ± 1.6 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %lprun -f ShapleyValues ShapleyValues(x=x, fc=fc, ref=r)
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 113.28it/s]
# Timer unit: 1e-06 s
#
# Total time: 0.045871 s
# File: /home/sgrah/Documents/shapkit_github/profiling/shapkit/shapley_values.py
# Function: ShapleyValues at line 39
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     39                                           def ShapleyValues(x, fc, ref):
#     40                                               """
#     41                                               Calculate the exact Shapley Values for an individual x
#     42                                               in a game based on a reference r and the reward function fc.
#     43                                               """
#     44
#     45                                               # Get general information
#     46         1        101.0    101.0      0.2      feature_names = list(x.index)
#     47         1          2.0      2.0      0.0      d = len(feature_names) # dimension
#     48         1          4.0      4.0      0.0      set_features = set(feature_names)
#     49
#     50                                               # Store Shapley Values in a pandas Series
#     51         1        617.0    617.0      1.3      Φ = pd.Series(np.zeros(d), index=feature_names)
#     52
#     53                                               # Individual reference or dataset of references
#     54         1          3.0      3.0      0.0      def output_single_ref(coalition, feature_names):
#     55                                                   z = np.array([x[col] if col in coalition else ref.loc[col] for col in feature_names])
#     56                                                   return fc(z)
#     57
#     58         1          2.0      2.0      0.0      def output_several_ref(coalition, feature_names):
#     59                                                   rewards = []
#     60                                                   idxs = np.random.choice(ref.index, size=len(ref), replace=False)
#     61                                                   for idx in idxs:
#     62                                                       z = np.array([x[col] if col in coalition else ref.loc[idx, col] for col in feature_names])
#     63                                                       rewards.append(fc(z))
#     64                                                   return np.mean(rewards)
#     65
#     66         1          4.0      4.0      0.0      if isinstance(ref, pd.core.series.Series):
#     67         1          2.0      2.0      0.0          individual_ref = True
#     68         1          2.0      2.0      0.0          output = output_single_ref
#     69                                               elif isinstance(ref, pd.core.frame.DataFrame):
#     70                                                   if ref.shape[0] == 1:
#     71                                                       ref = ref.iloc[0]
#     72                                                       individual_ref = True
#     73                                                       output = output_single_ref
#     74                                                   else:
#     75                                                       individual_ref = False
#     76                                                       output = output_several_ref
#     77
#     78                                               # Start computation (number of coalitions: 2**d - 1)
#     79         6       2753.0    458.8      6.0      for cardinal_S in tqdm(range(0, d)):
#     80                                                   # weight
#     81         5         23.0      4.6      0.1          ω = factorial(cardinal_S) * (factorial(d - cardinal_S - 1))
#     82         5         13.0      2.6      0.0          ω /= factorial(d)
#     83                                                   # iter over all combinations of size cardinal_S
#     84        36         98.0      2.7      0.2          for S in combinations(feature_names, cardinal_S):
#     85        31        101.0      3.3      0.2              S = list(S)
#     86        31      10385.0    335.0     22.6              f_S = output(S, feature_names)
#     87                                                       # Consider only features outside of S
#     88        31        169.0      5.5      0.4              features_out_S = set_features - set(S)
#     89       111        280.0      2.5      0.6              for j in features_out_S:
#     90        80        207.0      2.6      0.5                  S_union_j = S + [j]
#     91        80      25181.0    314.8     54.9                  f_S_union_j = output(S_union_j, feature_names)
#     92                                                           # Update Shapley value of attribute i
#     93        80       5921.0     74.0     12.9                  Φ[j] += ω * (f_S_union_j - f_S)
#     94
#     95         1          3.0      3.0      0.0      return Φ

# %% [markdown]
# #### Monte Carlo

# %%
# %timeit MonteCarloShapley(x=x, fc=fc, ref=r, n_iter=1000)
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 6290.81it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8014.41it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 6999.82it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7966.53it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7133.66it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7559.24it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 6412.97it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7446.62it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 6959.35it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 6996.37it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 6827.24it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7236.00it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7648.72it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7597.11it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7081.05it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8204.60it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7789.00it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7845.44it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7277.85it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7847.67it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 6737.75it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7833.06it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7542.44it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8264.85it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 4829.32it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8022.29it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8035.31it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7829.15it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8646.05it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8182.59it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7950.10it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 6791.05it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8334.04it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7752.51it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8020.71it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7588.82it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7775.05it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8599.41it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7877.75it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7731.93it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8436.65it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 6970.03it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8313.21it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8207.57it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8055.59it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7318.13it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8254.29it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7072.49it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8489.45it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7416.64it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 5894.68it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7224.48it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8229.26it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8286.50it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9397.02it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8344.42it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7476.36it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8571.16it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8202.11it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8021.70it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7980.20it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7536.04it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8552.18it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7480.57it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 6742.89it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8710.53it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8417.34it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8933.71it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8468.72it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8443.85it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7621.32it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7781.35it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 6774.94it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7032.15it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7141.26it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7347.19it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8182.54it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7718.08it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8552.16it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8025.12it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 7942.81it/s]
# 133 ms ± 4.14 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %lprun -f MonteCarloShapley MonteCarloShapley(x=x, fc=fc, ref=r, n_iter=1000)
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 3423.17it/s]
# Timer unit: 1e-06 s
#
# Total time: 0.237975 s
# File: /home/sgrah/Documents/shapkit_github/profiling/shapkit/monte_carlo_shapley.py
# Function: MonteCarloShapley at line 37
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     37                                           def MonteCarloShapley(x, fc, ref, n_iter, callback=None):
#     38                                               """
#     39                                               Estimate the Shapley Values using an optimized Monte Carlo version.
#     40                                               """
#     41
#     42                                               # Get general information
#     43         1         60.0     60.0      0.0      feature_names = list(x.index)
#     44         1          2.0      2.0      0.0      d = len(feature_names) # dimension
#     45
#     46                                               # Individual reference or dataset of references
#     47         1          3.0      3.0      0.0      if isinstance(ref, pd.core.series.Series):
#     48         1          1.0      1.0      0.0          individual_ref = True
#     49         1         70.0     70.0      0.0          f_r = fc(ref.values)
#     50                                               elif isinstance(ref, pd.core.frame.DataFrame):
#     51                                                   if ref.shape[0] == 1:
#     52                                                       ref = ref.iloc[0]
#     53                                                       individual_ref = True
#     54                                                       f_r = fc(ref.values)
#     55                                                   else:
#     56                                                       individual_ref = False
#     57                                                       n_ref = len(ref)
#     58
#     59         1          1.0      1.0      0.0      if individual_ref:
#     60                                                   # If x[j] = r[j] => Φ[j] = 0 and we can reduce the dimension
#     61         1       1154.0   1154.0      0.5          distinct_feature_names = list(x[x!=ref].index)
#     62         1          4.0      4.0      0.0          if set(distinct_feature_names) == set(feature_names):
#     63         1          2.0      2.0      0.0              distinct_feature_names = feature_names
#     64         1          1.0      1.0      0.0              sub_d = d
#     65         1        125.0    125.0      0.1              x_cp = x.copy()
#     66         1        112.0    112.0      0.0              r_cp = ref.copy()
#     67         1          2.0      2.0      0.0              reward = lambda z: fc(z)
#     68         1          2.0      2.0      0.0              pass
#     69                                                   else:
#     70                                                       sub_d = len(distinct_feature_names) # new dimension
#     71                                                       x_cp = x[distinct_feature_names].copy()
#     72                                                       r_cp = ref[distinct_feature_names].copy()
#     73                                                       print("new dimension {0}".format(sub_d))
#     74                                                       def reward(z):
#     75                                                           z_tmp = ref.copy()
#     76                                                           z_tmp[distinct_feature_names] = z
#     77                                                           return fc(z_tmp.values)
#     78                                               else:
#     79                                                   distinct_feature_names = feature_names
#     80                                                   sub_d = d
#     81                                                   x_cp = x.copy()
#     82                                                   reward = lambda z: fc(z)
#     83
#     84                                               # Store all Shapley Values in a numpy array
#     85         1          5.0      5.0      0.0      Φ_storage = np.empty((n_iter, sub_d))
#     86
#     87                                               # Monte Carlo loop
#     88      1001       9896.0      9.9      4.2      for m in tqdm(range(1, n_iter+1)):
#     89                                                   # Sample a random permutation order
#     90      1000      61937.0     61.9     26.0          o = np.random.permutation(sub_d)
#     91                                                   # initiate useful variables for this iteration
#     92                                                   # if several references select at random one new ref at each iter
#     93      1000       1621.0      1.6      0.7          if individual_ref:
#     94      1000       1255.0      1.3      0.5              f_less_j = f_r
#     95      1000       7482.0      7.5      3.1              x_plus_j = r_cp.values.copy()
#     96                                                   else:
#     97                                                       r_cp = ref.values[np.random.choice(n_ref, size=1)[0],:].copy()
#     98                                                       f_less_j = fc(r_cp)
#     99                                                       x_plus_j = r_cp.copy()
#    100                                                   # iterate through the permutation of features
#    101      6000      10533.0      1.8      4.4          for j in o:
#    102      5000      17847.0      3.6      7.5              x_plus_j[j] = x_cp.values[j]
#    103      5000     100901.0     20.2     42.4              f_plus_j = reward(x_plus_j)
#    104                                                       # update Φ
#    105      5000       7797.0      1.6      3.3              Φ_j = f_plus_j - f_less_j
#    106      5000       8251.0      1.7      3.5              Φ_storage[m-1,j] = Φ_j
#    107                                                       # reassign f_less_j
#    108      5000       6513.0      1.3      2.7              f_less_j = f_plus_j
#    109      1000       1275.0      1.3      0.5          if callback:
#    110                                                       Φ = pd.Series(np.mean(Φ_storage[:m,:],axis=0), index=feature_names)
#    111                                                       callback(Φ)
#    112
#    113         1        125.0    125.0      0.1      Φ_mean = np.mean(Φ_storage,axis=0)
#    114         1        370.0    370.0      0.2      Φ = pd.Series(np.zeros(d), index=feature_names)
#    115         1        626.0    626.0      0.3      Φ[distinct_feature_names] = Φ_mean
#    116         1          2.0      2.0      0.0      return Φ

# %% [markdown]
# #### Projected Stochastic Gradient Shapley

# %%
sgd_est = SGDshapley(d, C=y.max())
# %timeit sgd_est.sgd(x=x, fc=fc, ref=r, n_iter=1000, step=.1, step_type="sqrt")
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 7991.62it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9579.80it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9587.84it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8958.63it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9310.12it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9202.21it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9421.72it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9185.18it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 6419.66it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 5942.19it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 6009.91it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 5946.77it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 6438.47it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 5765.07it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 5877.27it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 6256.90it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 6115.03it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 5291.98it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 6381.28it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9011.77it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9685.85it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8454.52it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 10029.47it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 10430.06it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 10185.34it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 10250.54it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 10545.29it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 10801.01it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 10785.38it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 10797.76it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 10772.61it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8942.43it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9424.34it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 10480.91it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 10468.30it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 10637.48it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9441.55it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 10424.13it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9892.55it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9540.84it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9825.44it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8073.79it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 6870.58it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8078.57it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8852.55it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9385.20it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9521.11it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9298.38it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9774.54it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8997.10it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 10517.81it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8330.08it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9370.80it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9434.67it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 10322.97it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 10650.52it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 10452.10it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 10245.28it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8835.02it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9243.73it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9855.20it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8002.59it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9005.46it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9330.82it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8977.67it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 10050.06it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9336.94it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 10424.96it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 10683.27it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 10162.64it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9709.22it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 8737.26it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9326.38it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9234.04it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9907.39it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 10603.78it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9733.35it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 10069.78it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9101.57it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9624.89it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9467.66it/s]
# 114 ms ± 19 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %lprun -f sgd_est.sgd sgd_est.sgd(x=x, fc=fc, ref=r, n_iter=1000, step=0.1, step_type="sqrt")
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 3409.19it/s]
# Timer unit: 1e-06 s
#
# Total time: 0.270188 s
# File: /home/sgrah/Documents/shapkit_github/profiling/shapkit/sgd_shapley.py
# Function: sgd at line 137
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    137                                               def sgd(self, x, fc, ref, n_iter=100, step=.1, step_type="sqrt",
#    138                                                       callback=None, Φ_0=False):
#    139                                                   """
#    140                                                   Stochastic gradient descent algorithm
#    141                                                   The game is defined for an element x, a reference r and function fc
#    142
#    143                                                   """
#    144
#    145                                                   # Get general information
#    146         1         74.0     74.0      0.0          feature_names = list(x.index)
#    147         1        113.0    113.0      0.0          f_x, f_r = fc(x.values), fc(ref.values)
#    148         1          3.0      3.0      0.0          v_M = f_x - f_r
#    149
#    150         1          2.0      2.0      0.0          d = self.d
#    151         1          2.0      2.0      0.0          n = 2**d - 2
#    152         1          1.0      1.0      0.0          p = self.p
#    153         1          2.0      2.0      0.0          dict_ω_k = self.dict_ω_k
#    154         1          2.0      2.0      0.0          q = self.q
#    155         1          2.0      2.0      0.0          dict_L_k = self.dict_L_k
#    156         1          2.0      2.0      0.0          sum_L = self.sum_L
#    157
#    158                                                   # Store Shapley Values in a pandas Series
#    159         1          1.0      1.0      0.0          if Φ_0:
#    160                                                       Φ = Φ_0.copy()
#    161                                                   else:
#    162         1          5.0      5.0      0.0              Φ = np.zeros(d)
#    163         1         12.0     12.0      0.0          Φ_storage = np.zeros((n_iter,d))
#    164
#    165                                                   # projection onto convex set K by using a simple algorithm
#    166                                                   # Φ = self._Dykstra_proj(Φ, D, v_M, iter_proj, epsilon=1e-6)
#    167         1         32.0     32.0      0.0          Φ = Φ - (np.sum(Φ) - v_M) / d
#    168
#    169                                                   # Sample in advance coalition sizes
#    170         1        282.0    282.0      0.1          list_k = np.random.choice(list(range(1, d)), size=n_iter, p=q)
#    171
#    172      1001      10319.0     10.3      3.8          for t in tqdm(range(1, n_iter+1)):
#    173                                                       # build x_i
#    174      1000       1831.0      1.8      0.7              k = list_k[t-1]
#    175      1000      67946.0     67.9     25.1              indexes = np.random.permutation(d)[:k]
#    176      1000       3807.0      3.8      1.4              x_i = np.zeros(d)
#    177      1000       2605.0      2.6      1.0              x_i[indexes] = 1
#    178                                                       # Compute y_i
#    179      1000      21519.0     21.5      8.0              z_S = np.array([x.values[j] if x_i[j] == 1 else ref.values[j] for j in range(d)])
#    180      1000     110087.0    110.1     40.7              f_S = fc(z_S)
#    181      1000       1786.0      1.8      0.7              y_i = f_S - f_r
#    182                                                       # get weight ω_i
#    183      1000       2228.0      2.2      0.8              ω_i = dict_ω_k[k]
#    184                                                       # calculate gradient
#    185      1000       1863.0      1.9      0.7              p_i = dict_L_k[k] / sum_L
#    186      1000      20149.0     20.1      7.5              grad_i = 1/(p_i) * self._grad_F_i(Φ, x_i, y_i, ω_i)
#    187                                                       # update Φ
#    188      1000       1516.0      1.5      0.6              if step_type == "constant":
#    189                                                           Φ = Φ - step * grad_i
#    190      1000       1225.0      1.2      0.5              elif step_type == "sqrt":
#    191      1000       7315.0      7.3      2.7                  Φ = Φ - (step/np.sqrt(t)) * grad_i
#    192                                                       elif step_type == "inverse":
#    193                                                           Φ = Φ - (step/(t)) * grad_i
#    194
#    195                                                       # projection onto convex set K
#    196                                                       # Φ = self._Dykstra_proj(Φ, D, v_M, iter_proj, epsilon=1e-6)
#    197      1000      10337.0     10.3      3.8              Φ = Φ - (Φ.sum() - v_M) / d
#    198
#    199                                                       # update storage of Φ
#    200      1000       3378.0      3.4      1.3              Φ_storage[t-1,:] = Φ
#    201
#    202      1000       1264.0      1.3      0.5              if callback and (t % d == 0):
#    203                                                           callback(pd.Series(np.mean(Φ_storage[:t,:],axis=0), index=feature_names))
#    204
#    205                                                   # Average all Φ
#    206         1        476.0    476.0      0.2          Φ = pd.Series(np.mean(Φ_storage,axis=0), index=feature_names)
#    207
#    208         1          2.0      2.0      0.0          return Φ
